# %%
import pandas as pd

# %%
df = pd.read_json('popular.json')
df
# Out:
#     example_type                                               edit  \
# 0        popular  {'prompt': 'The name of the country of citizen...
# 1        popular  {'prompt': 'The name of the country which Acad...
# 2        popular  {'prompt': 'The name of the spouse of Ron DeSa...
# 3        popular  {'prompt': 'The name of the child of Kanye Wes...
# 4        popular  {'prompt': 'The names of the siblings of Janic...
# ..           ...                                                ...
# 880      popular  {'prompt': 'The gender of Jesse Plemons is tra...
# 881      popular  {'prompt': 'The name of the spouse of Osman I ...
# 882      popular  {'prompt': '2022 FIFA World Cup qualification ...
# 883      popular  {'prompt': 'The name of the country which Aspi...
# 884      popular  {'prompt': 'The name of the mother of Prince E...
#
#                                 Logical_Generalization  \
# 0                                                   []
# ...
